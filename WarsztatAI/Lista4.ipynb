# %% [markdown]
# # Michal Wilczkowski i Adrian Walczak

# %% [markdown]
# # Lista 4
#
# ## Pandas: dane tabluarne
#
# (6pkt + 3pkt)
#
# Na liście znajdują się 2 zadania. Podczas ćwiczeń wykonaj jedno z nich. Po rozwiązaniu zadania pokaż kod prowadzącemu i odpowiedz na **pytanie kontrolne** — tylko wtedy przyznajemy punkty. Dodatkowo prześlij zadanie na platformie skos.
#
# Zadanie dodatkowe oznaczone jest ⭐️. Za wykonanie zadania otrzymasz 3pkt.

# %% [markdown]
# ## Titanic Dataset
#
# Przeanalizuj zbiór danych [**Titanic Dataset**](https://www.kaggle.com/datasets/yasserh/titanic-dataset?utm_source=chatgpt.com). Znajdź ciekawe informacje i zależności.
#
# > **Uwaga:** Nie musisz wykonywać poniższego polecenia, ale może ono pomóc oszacować nakład pracy potrzebny na zdobycie maksymalnej liczby punktów. Możesz samodzielnie zbadać ten zbiór danych.
#
# ### Zadania
#
# Wczytaj bazę danych i wykonaj poniższe polecenia:
#
# 1. Wyświetl początek danych (`head()`) oraz opis statystyczny (`describe()`).
# 2. Znajdź wszystkich pasażerów płci żeńskiej, którzy przeżyli (`Survived == 1`).
# 3. Oblicz średnią i medianę ceny biletu (`Fare`).
# 4. Policz, ilu mężczyzn i kobiet znajduje się w danych (`value_counts()` dla kolumny `Sex`).
# 5. Oblicz procent przeżycia kobiet i mężczyzn w tym zbiorze.
# 6. Dodaj kolumnę `IsChild` — oznacz pasażerów poniżej 18 roku życia. Następnie zobacz, ilu z nich przeżyło.
# 7. Sprawdź, ilu pasażerów klasy 1 i klasy 3 przeżyło, używając filtrowania (`Pclass`).
# 8. Znajdź wszystkich pasażerów, którzy:
#     - zapłacili więcej niż średnia cena biletu (`Fare > mean_fare`),
#     - byli kobietami,
#     - oraz przeżyli.
#
#     Posortuj wynik malejąco po `Fare`.
#
# > **Wskazówka:** Całość można wykonać w ok. 13 linijkach kodu Pandas.

# %% [markdown]
# ## Sleep Health and Lifestyle Dataset
#
# Przeanalizuj zbiór danych [**Sleep Health and Lifestyle Dataset**](https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset). Znajdź ciekawe informacje i zależności.
#
# > **Uwaga:** Nie musisz wykonywać poniższego polecenia, ale może ono pomóc oszacować nakład pracy potrzebny na zdobycie maksymalnej liczby punktów. Możesz samodzielnie zbadać ten zbiór danych.
#
# ### Zadania
#
# Wczytaj bazę danych i wykonaj poniższe polecenia:
#
# 1. Wyświetl początek danych (`head()`) oraz opis statystyczny (`describe()`).
# 2. Oblicz średni czas snu i średni poziom stresu w całej grupie.
# 3. Sprawdź, czy dłuższy sen wiąże się z lepszą jakością snu, używając korelacji (`corr()`).
#    > Jeśli korelacja bliska 1 – oznacza silną zależność (więcej snu = lepsza jakość).
# 4. Znajdź osoby, które:
#    - mają `Quality of Sleep >= 8`
#    - i `Stress Level <= 5`
# 5. Stwórz kolumnę `Lifestyle Score`, która będzie prostą miarą jakości stylu życia:
#    Lifestyle Score = (Quality of Sleep) + (Physical Activity Level / 10) - (Stress Level / 2)
# 6. Sprawdź, czy osoby z kategorią BMI „Overweight” mają niższą jakość snu niż osoby z „Normal”.
# 7. Sprawdź, czy osoby z wysokim poziomem stresu (`Stress Level > 7`) śpią krócej niż 6 godzin.
# 8. Stwórz kolumny z ciśnienia krwi:
#
#    ```python
#    df[['Systolic', 'Diastolic']] = df['Blood Pressure'].str.split('/', expand=True).astype(int)
#    ```
#
#    Następnie znajdź wszystkich, którzy:
#
#    * mają `Systolic > 125`,
#    * `BMI Category == "Overweight"`,
#    * `Sleep Duration < 6.5`,
#
#    i posortuj ich malejąco po `Stress Level`.
#
# > **Wskazówka:** Całość można wykonać w ok. 12 linijkach kodu Pandas.

# %%
data = pd.read_csv('./Sleep_health_and_lifestyle_dataset.csv')

# %%
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
data['Sleep Duration'].mean()
# Out:
# np.float64(7.132085561497325)

# %%
data['Stress Level'].mean()
# Out:
# np.float64(5.385026737967914)

# %%
data['Sleep Duration'].corr(data['Quality of Sleep'])
# Out:
# np.float64(0.8832130004106171)

# %%
data[(data['Quality of Sleep'] >= 8) & (data['Stress Level'] <= 5)]
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 32          33  Female   31              Nurse             7.9
# 50          51    Male   32           Engineer             7.5
# 51          52    Male   32           Engineer             7.5
# 84          85    Male   35  Software Engineer             7.5
# 85          86  Female   35         Accountant             7.2
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# 373        374  Female   59              Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 32                  8                       75             4  Normal Weight
# 50                  8                       45             3         Normal
# 51                  8                       45             3         Normal
# 84                  8                       60             5  Normal Weight
# 85                  8                       60             4         Normal
# ..                ...                      ...           ...            ...
# 369                 9                       75             3     Overweight
# 370                 9                       75             3     Overweight
# 371                 9                       75             3     Overweight
# 372                 9                       75             3     Overweight
# 373                 9                       75             3     Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 32          117/76          69         6800            NaN
# 50          120/80          70         8000            NaN
# 51          120/80          70         8000            NaN
# 84          120/80          70         8000            NaN
# 85          115/75          68         7000            NaN
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [176 rows x 13 columns]

# %%
data['Lifestyle Score'] = data['Quality of Sleep'] + (data['Physical Activity Level'] / 10) - (data['Stress Level'] / 2)

# %%
data[data['BMI Category'] == 'Overweight']['Quality of Sleep'].mean()
# Out:
# np.float64(6.898648648648648)

# %%
data[data['BMI Category'] == 'Normal']['Quality of Sleep'].mean()
# Out:
# np.float64(7.661538461538462)

# %%
data.groupby('BMI Category')['Quality of Sleep'].mean()
# Out:
# BMI Category
# Normal           7.661538
# Normal Weight    7.428571
# Obese            6.400000
# Overweight       6.898649
# Name: Quality of Sleep, dtype: float64

# %%
data[data['Stress Level'] > 7]['Sleep Duration'].median()
#Spia troche dluzej niz 6
# Out:
# 6.0

# %%
data[['Systolic', 'Diastolic']] = data['Blood Pressure'].str.split('/', expand=True).astype(int)

# %%
data.query('Systolic > 125 and `BMI Category` == "Overweight" and `Sleep Duration` < 6.5').sort_values('Stress Level')
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 68          69  Female   33          Scientist             6.2
# 69          70  Female   33          Scientist             6.2
# 106        107  Female   37              Nurse             6.1
# 191        192    Male   43        Salesperson             6.4
# 187        188    Male   43        Salesperson             6.3
# 222        223    Male   44        Salesperson             6.3
# 221        222    Male   44        Salesperson             6.4
# 227        228    Male   44        Salesperson             6.3
# 229        230    Male   44        Salesperson             6.3
# 223        224    Male   44        Salesperson             6.4
# 225        226    Male   44        Salesperson             6.3
# 231        232    Male   44        Salesperson             6.3
# 233        234    Male   44        Salesperson             6.3
# 236        237    Male   44        Salesperson             6.4
# 235        236    Male   44        Salesperson             6.3
# 248        249    Male   44        Salesperson             6.4
# 242        243    Male   44        Salesperson             6.4
# 238        239    Male   44        Salesperson             6.3
# 239        240    Male   44        Salesperson             6.4
# 241        242    Male   44        Salesperson             6.3
# 246        247    Male   44        Salesperson             6.3
# 244        245    Male   44        Salesperson             6.3
# 81          82  Female   34          Scientist             5.8
# 80          81  Female   34          Scientist             5.8
# 265        266  Female   48              Nurse             5.9
# 267        268  Female   49              Nurse             6.2
# 268        269  Female   49              Nurse             6.0
# 269        270  Female   49              Nurse             6.1
# 270        271  Female   49              Nurse             6.1
# 271        272  Female   49              Nurse             6.1
# 272        273  Female   49              Nurse             6.1
# 273        274  Female   49              Nurse             6.2
# 274        275  Female   49              Nurse             6.2
# 275        276  Female   49              Nurse             6.2
# 278        279  Female   50              Nurse             6.1
# 280        281  Female   50              Nurse             6.0
# 281        282  Female   50              Nurse             6.1
# 282        283  Female   50              Nurse             6.0
# 283        284  Female   50              Nurse             6.0
# 284        285  Female   50              Nurse             6.0
# 285        286  Female   50              Nurse             6.0
# 286        287  Female   50              Nurse             6.0
# 287        288  Female   50              Nurse             6.0
# 288        289  Female   50              Nurse             6.0
# 289        290  Female   50              Nurse             6.1
# 290        291  Female   50              Nurse             6.0
# 291        292  Female   50              Nurse             6.1
# 292        293  Female   50              Nurse             6.1
# 293        294  Female   50              Nurse             6.0
# 294        295  Female   50              Nurse             6.1
# 295        296  Female   50              Nurse             6.0
# 296        297  Female   50              Nurse             6.1
# 297        298  Female   50              Nurse             6.1
# 303        304  Female   51              Nurse             6.0
# 304        305  Female   51              Nurse             6.1
# 305        306  Female   51              Nurse             6.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 68                  6                       50             6   Overweight
# 69                  6                       50             6   Overweight
# 106                 6                       42             6   Overweight
# 191                 6                       45             7   Overweight
# 187                 6                       45             7   Overweight
# 222                 6                       45             7   Overweight
# 221                 6                       45             7   Overweight
# 227                 6                       45             7   Overweight
# 229                 6                       45             7   Overweight
# 223                 6                       45             7   Overweight
# 225                 6                       45             7   Overweight
# 231                 6                       45             7   Overweight
# 233                 6                       45             7   Overweight
# 236                 6                       45             7   Overweight
# 235                 6                       45             7   Overweight
# 248                 6                       45             7   Overweight
# 242                 6                       45             7   Overweight
# 238                 6                       45             7   Overweight
# 239                 6                       45             7   Overweight
# 241                 6                       45             7   Overweight
# 246                 6                       45             7   Overweight
# 244                 6                       45             7   Overweight
# 81                  4                       32             8   Overweight
# 80                  4                       32             8   Overweight
# 265                 6                       90             8   Overweight
# 267                 6                       90             8   Overweight
# 268                 6                       90             8   Overweight
# 269                 6                       90             8   Overweight
# 270                 6                       90             8   Overweight
# 271                 6                       90             8   Overweight
# 272                 6                       90             8   Overweight
# 273                 6                       90             8   Overweight
# 274                 6                       90             8   Overweight
# 275                 6                       90             8   Overweight
# 278                 6                       90             8   Overweight
# 280                 6                       90             8   Overweight
# 281                 6                       90             8   Overweight
# 282                 6                       90             8   Overweight
# 283                 6                       90             8   Overweight
# 284                 6                       90             8   Overweight
# 285                 6                       90             8   Overweight
# 286                 6                       90             8   Overweight
# 287                 6                       90             8   Overweight
# 288                 6                       90             8   Overweight
# 289                 6                       90             8   Overweight
# 290                 6                       90             8   Overweight
# 291                 6                       90             8   Overweight
# 292                 6                       90             8   Overweight
# 293                 6                       90             8   Overweight
# 294                 6                       90             8   Overweight
# 295                 6                       90             8   Overweight
# 296                 6                       90             8   Overweight
# 297                 6                       90             8   Overweight
# 303                 6                       90             8   Overweight
# 304                 6                       90             8   Overweight
# 305                 6                       90             8   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  Lifestyle Score  \
# 0           126/83          77         4200            NaN              7.2
# 68          128/85          76         5500            NaN              8.0
# 69          128/85          76         5500            NaN              8.0
# 106         126/83          77         4200            NaN              7.2
# 191         130/85          72         6000       Insomnia              7.0
# 187         130/85          72         6000       Insomnia              7.0
# 222         130/85          72         6000       Insomnia              7.0
# 221         130/85          72         6000       Insomnia              7.0
# 227         130/85          72         6000       Insomnia              7.0
# 229         130/85          72         6000       Insomnia              7.0
# 223         130/85          72         6000       Insomnia              7.0
# 225         130/85          72         6000       Insomnia              7.0
# 231         130/85          72         6000       Insomnia              7.0
# 233         130/85          72         6000       Insomnia              7.0
# 236         130/85          72         6000       Insomnia              7.0
# 235         130/85          72         6000       Insomnia              7.0
# 248         130/85          72         6000            NaN              7.0
# 242         130/85          72         6000       Insomnia              7.0
# 238         130/85          72         6000       Insomnia              7.0
# 239         130/85          72         6000       Insomnia              7.0
# 241         130/85          72         6000       Insomnia              7.0
# 246         130/85          72         6000       Insomnia              7.0
# 244         130/85          72         6000       Insomnia              7.0
# 81          131/86          81         5200    Sleep Apnea              3.2
# 80          131/86          81         5200    Sleep Apnea              3.2
# 265         140/95          75        10000    Sleep Apnea             11.0
# 267         140/95          75        10000            NaN             11.0
# 268         140/95          75        10000    Sleep Apnea             11.0
# 269         140/95          75        10000    Sleep Apnea             11.0
# 270         140/95          75        10000    Sleep Apnea             11.0
# 271         140/95          75        10000    Sleep Apnea             11.0
# 272         140/95          75        10000    Sleep Apnea             11.0
# 273         140/95          75        10000    Sleep Apnea             11.0
# 274         140/95          75        10000    Sleep Apnea             11.0
# 275         140/95          75        10000    Sleep Apnea             11.0
# 278         140/95          75        10000       Insomnia             11.0
# 280         140/95          75        10000            NaN             11.0
# 281         140/95          75        10000    Sleep Apnea             11.0
# 282         140/95          75        10000    Sleep Apnea             11.0
# 283         140/95          75        10000    Sleep Apnea             11.0
# 284         140/95          75        10000    Sleep Apnea             11.0
# 285         140/95          75        10000    Sleep Apnea             11.0
# 286         140/95          75        10000    Sleep Apnea             11.0
# 287         140/95          75        10000    Sleep Apnea             11.0
# 288         140/95          75        10000    Sleep Apnea             11.0
# 289         140/95          75        10000    Sleep Apnea             11.0
# 290         140/95          75        10000    Sleep Apnea             11.0
# 291         140/95          75        10000    Sleep Apnea             11.0
# 292         140/95          75        10000    Sleep Apnea             11.0
# 293         140/95          75        10000    Sleep Apnea             11.0
# 294         140/95          75        10000    Sleep Apnea             11.0
# 295         140/95          75        10000    Sleep Apnea             11.0
# 296         140/95          75        10000    Sleep Apnea             11.0
# 297         140/95          75        10000    Sleep Apnea             11.0
# 303         140/95          75        10000    Sleep Apnea             11.0
# 304         140/95          75        10000    Sleep Apnea             11.0
# 305         140/95          75        10000    Sleep Apnea             11.0
#
#      Systolic  Diastolic
# 0         126         83
# 68        128         85
# 69        128         85
# 106       126         83
# 191       130         85
# 187       130         85
# 222       130         85
# 221       130         85
# 227       130         85
# 229       130         85
# 223       130         85
# 225       130         85
# 231       130         85
# 233       130         85
# 236       130         85
# 235       130         85
# 248       130         85
# 242       130         85
# 238       130         85
# 239       130         85
# 241       130         85
# 246       130         85
# 244       130         85
# 81        131         86
# 80        131         86
# 265       140         95
# 267       140         95
# 268       140         95
# 269       140         95
# 270       140         95
# 271       140         95
# 272       140         95
# 273       140         95
# 274       140         95
# 275       140         95
# 278       140         95
# 280       140         95
# 281       140         95
# 282       140         95
# 283       140         95
# 284       140         95
# 285       140         95
# 286       140         95
# 287       140         95
# 288       140         95
# 289       140         95
# 290       140         95
# 291       140         95
# 292       140         95
# 293       140         95
# 294       140         95
# 295       140         95
# 296       140         95
# 297       140         95
# 303       140         95
# 304       140         95
# 305       140         95

# %% [markdown]
# # ⭐️ Most Streamed Spotify Songs 2023
#
# Odpowiedz na poniższe pytania dotyczące zbioru danych.
# Możesz wymienić dowolnych 7 zadań na własne — pamiętaj jednak, by nie były zbyt proste!

# %%
import pandas as pd

df = pd.read_csv('./spotify-2023.csv', encoding='latin1')

df.columns = df.columns.str.strip()

numeric_cols = [
    'artist_count',
    'released_year', 'released_month', 'released_day',
    'in_spotify_playlists', 'in_spotify_charts', 'streams',
    'in_apple_playlists', 'in_apple_charts',
    'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts',
    'bpm',
    'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
    'instrumentalness_%', 'liveness_%', 'speechiness_%'
]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

int_cols = [
    'artist_count', 'released_year', 'released_month', 'released_day',
    'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists',
    'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts',
    'in_shazam_charts', 'bpm'
]

for col in int_cols:
    if df[col].notna().all():
        df[col] = df[col].astype(int)

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               952 non-null    float64
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   874 non-null    float64
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      896 non-null    float64
#  14  bpm                   953 non-null    int64
#  15  key                   858 non-null    object
#  16  mode                  953 non-null    object
#  17  danceability_%        953 non-null    int64
#  18  valence_%             953 non-null    int64
#  19  energy_%              953 non-null    int64
#  20  acousticness_%        953 non-null    int64
#  21  instrumentalness_%    953 non-null    int64
#  22  liveness_%            953 non-null    int64
#  23  speechiness_%         953 non-null    int64
# dtypes: float64(3), int64(17), object(4)
# memory usage: 178.8+ KB
# None

# %% [markdown]
# ## Zadanie 1.
#
# **Które utwory są najczęściej dodawane do playlist (suma ze wszystkich platform)?**
#
# **Rozwiązanie:**

# %%
df['sum_playlist'] = df['in_spotify_playlists'] + df['in_apple_playlists'] + df['in_deezer_playlists']
df.sort_values('sum_playlist', ascending=False).head(10)
# Out:
#                                         track_name            artist(s)_name  \
# 657                                           Lost               Frank Ocean
# 110                                    Money Trees  Kendrick Lamar, Jay Rock
# 41   Sunflower - Spider-Man: Into the Spider-Verse     Post Malone, Swae Lee
# 14                                       As It Was              Harry Styles
# 71                                      Heat Waves             Glass Animals
# 166        Every Breath You Take - Remastered 2003                The Police
# 424         Running Up That Hill (A Deal With God)                 Kate Bush
# 186                                   Pink + White               Frank Ocean
# 115                                 No Role Modelz                   J. Cole
# 187                                        Circles               Post Malone
#
#      artist_count  released_year  released_month  released_day  \
# 657             1           2012               1             1
# 110             2           2012               1             1
# 41              2           2018              10             9
# 14              1           2022               3            31
# 71              1           2020               6            28
# 166             1           1983               1             6
# 424             1           1985               9            16
# 186             1           2016               8            20
# 115             1           2014              12             9
# 187             1           2019               8            30
#
#      in_spotify_playlists  in_spotify_charts       streams  \
# 657                 29499                 11  8.222397e+08
# 110                 26792                 32  1.093606e+09
# 41                  24094                 78  2.808097e+09
# 14                  23575                130  2.513188e+09
# 71                  22543                 63  2.557976e+09
# 166                 22439                 19  1.593271e+09
# 424                 21811                  0  1.024858e+09
# 186                 21574                 30  8.063971e+08
# 115                 21164                 36  1.791001e+09
# 187                 19664                 16  2.132336e+09
#
#      in_apple_playlists  ...  key   mode  danceability_%  valence_%  energy_%  \
# 657                 124  ...   A#  Minor              91         49        61
# 110                  69  ...    E  Minor              74         37        53
# 41                  372  ...    D  Major              76         91        50
# 14                  403  ...   F#  Minor              52         66        73
# 71                  386  ...    B  Major              76         53        53
# 166                 211  ...   C#  Major              82         73        45
# 424                 117  ...   A#  Minor              63         20        55
# 186                 112  ...    A  Major              54         54        55
# 115                  80  ...   A#  Minor              70         47        52
# 187                 391  ...  NaN  Major              70         59        75
#
#     acousticness_% instrumentalness_%  liveness_%  speechiness_%  sum_playlist
# 657              3                  0          17             22       30210.0
# 110              7                  0          21             10       27556.0
# 41              54                  0           7              5       25309.0
# 14              34                  0          31              6       24841.0
# 71              44                  0           9              9       23636.0
# 166             54                  0           7              3       23579.0
# 424             72                  0           6              6       22604.0
# 186             67                  0          42             11       21952.0
# 115             30                  0           6             33       21720.0
# 187             24                  0           9              4       20688.0
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Zadanie 2.
#
# **Czy bardziej taneczne utwory (`danceability_%`) mają wyższą energię (`energy_%`)?** Sprawdź współczynnik korelacji.
#
# **Rozwiązanie:**

# %%
df['danceability_%'].corr(df['energy_%'])
# Out:
# np.float64(0.19809484837625718)

# %% [markdown]
# ## Zadanie 3.
#
# **Które utwory są "taneczne i smutne"?** Czyli `danceability_% > 75` i `valence_% < 50`. Użyj `query()`.
#
# **Rozwiązanie:**

# %%
df.query('`danceability_%` > 75 and `valence_%` < 50')
#fukumean 	Gunna smutne?
# Major Distribution 	Drake, 21 Savage smutne?
# Out:
#              track_name               artist(s)_name  artist_count  \
# 8              fukumean                        Gunna             1
# 58                  S91                      Karol G             1
# 64              Hey Mor                  Ozuna, Feid             2
# 87      Me Porto Bonito  Chencho Corleone, Bad Bunny             2
# 88               Makeba                         Jain             1
# ..                  ...                          ...           ...
# 931  Major Distribution             Drake, 21 Savage             2
# 933      Vigilante Shit                 Taylor Swift             1
# 935               On BS             Drake, 21 Savage             2
# 939         Spin Bout U             Drake, 21 Savage             2
# 945     BackOutsideBoyz                        Drake             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 8             2023               5            15                  1096
# 58            2023               7            14                   525
# 64            2022              10             6                  4637
# 87            2022               5             6                  8870
# 88            2015               6            22                  6060
# ..             ...             ...           ...                   ...
# 931           2022              11             4                  1545
# 933           2022              10            21                  1948
# 935           2022              11             4                  1338
# 939           2022              11             4                  1652
# 945           2022              11             4                  1045
#
#      in_spotify_charts       streams  in_apple_playlists  ...  key   mode  \
# 8                   83  9.521732e+07                  60  ...   C#  Minor
# 58                  41  1.601133e+07                  34  ...  NaN  Minor
# 64                  38  6.740727e+08                  63  ...   C#  Minor
# 87                  43  1.440758e+09                 104  ...   C#  Minor
# 88                  53  1.654841e+08                 150  ...    D  Major
# ..                 ...           ...                 ...  ...  ...    ...
# 931                  0  1.548632e+08                  22  ...   G#  Minor
# 933                  0  2.536508e+08                  12  ...    E  Minor
# 935                  0  1.704139e+08                   9  ...    A  Major
# 939                  2  1.983655e+08                  26  ...    G  Major
# 945                  0  9.336754e+07                   8  ...    F  Minor
#
#      danceability_%  valence_%  energy_% acousticness_% instrumentalness_%  \
# 8                85         22        62             12                  0
# 58               86         42        72             59                  0
# 64               90         40        59              0                  0
# 87               91         43        71              9                  0
# 88               82         40        66             39                 51
# ..              ...        ...       ...            ...                ...
# 931              91         23        55              1                  0
# 933              80         16        28             17                  0
# 935              84         33        36              2                  0
# 939              77         20        70              1                  0
# 945              85         40        43              4                  0
#
#      liveness_%  speechiness_%  sum_playlist
# 8            28              9        1204.0
# 58            9             19         598.0
# 64           10             29        4789.0
# 87            9              8        9115.0
# 88           25              7           NaN
# ..          ...            ...           ...
# 931           7             32        1582.0
# 933          12             39        1976.0
# 935          39             59        1354.0
# 939          16              5        1688.0
# 945          39             32        1055.0
#
# [83 rows x 25 columns]

# %% [markdown]
# ## Zadanie 4.
#
# **Jakie jest średnie tempo (`bpm`) wszystkich utworów wydanych po 2020 roku?**

# %%
df[df['released_year'] > 2020]['bpm'].mean()
# Out:
# np.float64(123.17672413793103)

# %% [markdown]
# ## Zadanie 5.
#
# **Znajdź najżywszy (`liveness_%`) i najbardziej instrumentalny (`instrumentalness_%`) utwór.** Skorzystaj z `idxmax()`.
#
# **Rozwiązanie:**

# %%
df.iloc[df['liveness_%'].idxmax()]
# Out:
# track_name                                       Vai Lï¿½ï¿½ Em Casa
# artist(s)_name          Marï¿½ï¿½lia Mendonï¿½ï¿½a, George Henrique &
# artist_count                                                        2
# released_year                                                    2021
# released_month                                                     10
# released_day                                                       22
# in_spotify_playlists                                              772
# in_spotify_charts                                                   0
# streams                                                   263894529.0
# in_apple_playlists                                                  7
# in_apple_charts                                                     3
# in_deezer_playlists                                              89.0
# in_deezer_charts                                                    0
# in_shazam_charts                                                  0.0
# bpm                                                               158
# key                                                                G#
# mode                                                            Minor
# danceability_%                                                     46
# valence_%                                                          62
# energy_%                                                           83
# acousticness_%                                                     53
# instrumentalness_%                                                  0
# liveness_%                                                         97
# speechiness_%                                                      28
# sum_playlist                                                    868.0
# Name: 601, dtype: object

# %%
df.iloc[df['instrumentalness_%'].idxmax()]
# Out:
# track_name              Alien Blues
# artist(s)_name             Vundabar
# artist_count                      1
# released_year                  2015
# released_month                    7
# released_day                     24
# in_spotify_playlists           1930
# in_spotify_charts                 0
# streams                 370068639.0
# in_apple_playlists                3
# in_apple_charts                   0
# in_deezer_playlists            28.0
# in_deezer_charts                  0
# in_shazam_charts                1.0
# bpm                              82
# key                              D#
# mode                          Major
# danceability_%                   47
# valence_%                        44
# energy_%                         76
# acousticness_%                    8
# instrumentalness_%               91
# liveness_%                        9
# speechiness_%                     3
# sum_playlist                 1961.0
# Name: 684, dtype: object

# %% [markdown]
# ## Zadanie 6.
#
# **Oblicz średnią energię dla utworów z BPM pomiędzy 90 a 130.** Użyj `between()` i `.mean()`.
#
# **Rozwiązanie:**

# %%
df[df['bpm'].between(90, 130)]['energy_%'].mean()
# Out:
# np.float64(66.49806201550388)

# %% [markdown]
# ## Zadanie 7.
#
# **Sprawdź, czy utwory z tonacją Major mają wyższy średni `valence_%` (czyli bardziej „pozytywne emocje”) niż Minor.**
#
# **Rozwiązanie:**

# %%
df[df['mode'] == "Major"]['valence_%'].mean()
# Out:
# np.float64(50.13818181818182)

# %%
df[df['mode'] == "Minor"]['valence_%'].mean()
#Tak
# Out:
# np.float64(53.19602977667494)

# %% [markdown]
# ## Zadanie 8.
#
# **Który utwór ma najwyższy stosunek energii do akustyczności?** Oblicz nową kolumnę `energy_to_acoustic` i znajdź maksimum.
#
# **Rozwiązanie:**

# %%
df['energy_to_acoustic'] = df['energy_%'] / df['acousticness_%']
df.iloc[df['energy_to_acoustic'].idxmax()]
# Out:
# track_name               Like Crazy
# artist(s)_name                Jimin
# artist_count                      1
# released_year                  2023
# released_month                    3
# released_day                     24
# in_spotify_playlists            596
# in_spotify_charts                68
# streams                 363369738.0
# in_apple_playlists                8
# in_apple_charts                 104
# in_deezer_playlists            23.0
# in_deezer_charts                  2
# in_shazam_charts               29.0
# bpm                             120
# key                               G
# mode                          Major
# danceability_%                   63
# valence_%                        36
# energy_%                         73
# acousticness_%                    0
# instrumentalness_%                0
# liveness_%                       36
# speechiness_%                     4
# sum_playlist                  627.0
# energy_to_acoustic              inf
# Name: 19, dtype: object

# %% [markdown]
# ## Zadanie 9.
#
# **Które utwory mają ekstremalne (nietypowe) tempo — poniżej 70 lub powyżej 160 BPM — ale mimo to mają wysoką taneczność (`danceability_% > 70`)?**
#
# **Rozwiązanie:**

# %%
df[((df['bpm'] < 70) | (df['bpm'] > 160)) & (df['danceability_%'] > 70)]
# Out:
#                               track_name  \
# 9                        La Bebe - Remix
# 34                                   TQG
# 78                            Yandel 150
# 91             What It Is (Solo Version)
# 227                               Normal
# 261                        X SI VOLVEMOS
# 306                              La Bebe
# 356                                WANDA
# 368                          LA CANCIï¿½
# 456                        Love Language
# 547                               Volvï¿
# 594                               Sobrio
# 607                                 2055
# 632                             AM Remix
# 674                           Contection
# 708                               Jordan
# 794                           Mr. Morale
# 837  La Llevo Al Cielo (Ft. ï¿½ï¿½engo F
# 846                         Keep Driving
# 885         Si Te La Encuentras Por Ahï¿
# 928                    California Breeze
#
#                                         artist(s)_name  artist_count  \
# 9                                Peso Pluma, Yng Lvcas             2
# 34                                    Karol G, Shakira             2
# 78                                        Yandel, Feid             2
# 91                                             Doechii             1
# 227                                               Feid             1
# 261                              Karol G, Romeo Santos             2
# 306                                          Yng Lvcas             1
# 356                                            Quevedo             1
# 368                                J Balvin, Bad Bunny             2
# 456                                                SZA             1
# 547                                Aventura, Bad Bunny             2
# 594                                             Maluma             1
# 607                                      Sleepy hallow             1
# 632                    J Balvin, Nio Garcia, Bad Bunny             3
# 674                                  GODZZ__-, Zakaria             2
# 708                                        Ryan Castro             1
# 794                        Kendrick Lamar, Tanna Leone             2
# 837  Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corl...             4
# 846                                       Harry Styles             1
# 885                                               Feid             1
# 928                                           Lil Baby             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 9             2023               3            17                  2953
# 34            2023               2            23                  4284
# 78            2022              12            20                  3618
# 91            2023               3            17                   804
# 227           2022               7             8                  2461
# 261           2023               2             2                  2127
# 306           2021              12            24                   489
# 356           2023               1            20                   888
# 368           2019               6            28                  6398
# 456           2022              12             9                  1127
# 547           2021               8             3                  5375
# 594           2021               7             8                  3506
# 607           2021               4            14                  2226
# 632           2021               6            24                  6556
# 674           2020               1            16                  6955
# 708           2021               4            30                  2844
# 794           2022               5            13                  1860
# 837           2022               5            20                  3559
# 846           2022               5            20                  2094
# 885           2022               8             5                  1379
# 928           2022              10            14                   991
#
#      in_spotify_charts       streams  in_apple_playlists  ...   mode  \
# 9                   44  5.536341e+08                  49  ...  Minor
# 34                  49  6.189904e+08                 115  ...  Minor
# 78                  38  5.856954e+08                  47  ...  Minor
# 91                  25  9.513200e+07                  29  ...  Minor
# 227                 36  4.592764e+08                  47  ...  Minor
# 261                 33  2.666245e+08                  45  ...  Minor
# 306                 17  1.919456e+08                   4  ...  Minor
# 356                 22  1.753993e+08                  11  ...  Minor
# 368                 31  1.435128e+09                 177  ...  Major
# 456                  0  1.108491e+08                  16  ...  Minor
# 547                 10  6.738011e+08                 138  ...  Major
# 594                 10  5.136439e+08                 103  ...  Major
# 607                  0  6.245155e+08                  29  ...  Minor
# 632                  0  5.285447e+08                  93  ...  Minor
# 674                  0  1.180896e+09                  65  ...  Minor
# 708                  2  3.940303e+08                  29  ...  Minor
# 794                  0  5.868742e+07                   1  ...  Major
# 837                  3  3.331465e+08                  36  ...  Minor
# 846                  1  2.360607e+08                   8  ...  Major
# 885                  4  1.790614e+08                  23  ...  Minor
# 928                  0  8.555936e+07                  36  ...  Minor
#
#      danceability_%  valence_%  energy_%  acousticness_% instrumentalness_%  \
# 9                81         56        48              21                  0
# 34               72         61        63              67                  0
# 78               78         58        73               5                  0
# 91               74         76        76               6                  0
# 227              71         59        56               4                  0
# 261              79         58        78              34                  0
# 306              78         75        46              62                  0
# 356              72         96        63              25                  0
# 368              75         43        65              15                  0
# 456              71         55        26              85                  0
# 547              73         79        86              42                  0
# 594              76         63        77              14                  0
# 607              78         65        52              46                  0
# 632              74         79        66              11                  0
# 674              81         83        75              14                  0
# 708              80         71        68               6                  0
# 794              73         26        54              30                  0
# 837              80         77        85              11                  0
# 846              72         90        48              32                  0
# 885              74         46        58              15                  0
# 928              74         22        67               0                  0
#
#     liveness_%  speechiness_%  sum_playlist  energy_to_acoustic
# 9            8             33        3068.0            2.285714
# 34           9             28        4583.0            0.940299
# 78          10              7        3745.0           14.600000
# 91          10              9         857.0           12.666667
# 227         27             12        2553.0           14.000000
# 261         11             25        2225.0            2.294118
# 306         12             35         498.0            0.741935
# 356         21              7         906.0            2.520000
# 368         11             32        6880.0            4.333333
# 456         13              8        1151.0            0.305882
# 547          7             18        5646.0            2.047619
# 594         15             22        3709.0            5.500000
# 607         12             31        2299.0            1.130435
# 632          8             16        6716.0            6.000000
# 674         29             34        7418.0            5.357143
# 708         10             37        2908.0           11.333333
# 794         34             32        1864.0            1.800000
# 837         17             14        3626.0            7.727273
# 846         18             23        2120.0            1.500000
# 885         13              8        1420.0            3.866667
# 928         11             46        1040.0                 inf
#
# [21 rows x 26 columns]

# %% [markdown]
# ## Zadanie 10.
#
# **Policz, ile utworów przekracza 100 mln odtworzeń (`streams > 100_000_000`). Jaki procent wszystkich to stanowi?**
#
# **Rozwiązanie:**

# %%
sum(df['streams'] > 100_000_000)
# Out:
# 800

# %%
sum(df['streams'] > 100_000_000) / df.shape[0]
# Out:
# 0.8394543546694648

# %% [markdown]
# ## Zadanie 11.
#
# **Znajdź utwory, które mają wysoką energię (`energy_% > 85`) i jednocześnie są bardzo często wyszukiwane na Shazam (`in_shazam_charts > 500`).
# Posortuj malejąco po liczbie wyszukiwań.**
#
# **Rozwiązanie:**

# %%
df[(df['energy_%'] > 85) & (df['in_shazam_charts'] > 50)].sort_values('in_shazam_charts', ascending=False)
# Out:
#                                     track_name  \
# 653                           The Next Episode
# 51                          Baby Don't Hurt Me
# 42                             I'm Good (Blue)
# 121              Miracle (with Ellie Goulding)
# 152                               Danza Kuduro
# 102                                   Chemical
# 382                                  TRUSTFALL
# 132                                      Radio
# 144                                      QUEMA
# 31                                       TULUM
# 70                                  BABY HELLO
# 25                                 SABOR FRESA
# 60                                      Tï¿½ï¿
# 624  Smells Like Teen Spirit - Remastered 2021
# 888                            Mary On A Cross
# 630                             Mr. Brightside
# 174                               ýýýýýýýýýýýý
# 849               Only Love Can Hurt Like This
# 879                             Afraid To Feel
# 871                        Sweet Child O' Mine
# 305                                      HAPPY
# 604                                     No Lie
# 264                                       I AM
# 267                                      Super
#
#                           artist(s)_name  artist_count  released_year  \
# 653                  Dr. Dre, Snoop Dogg             2           1999
# 51   David Guetta, Anne-Marie, Coi Leray             3           2023
# 42              Bebe Rexha, David Guetta             2           2022
# 121        Calvin Harris, Ellie Goulding             2           2023
# 152                    Don Omar, Lucenzo             2           2010
# 102                          Post Malone             1           2023
# 382                                 P!nk             1           2023
# 132                         Lana Del Rey             1           2011
# 144         Sog, Ryan Castro, Peso Pluma             3           2023
# 31            Peso Pluma, Grupo Frontera             2           2023
# 70              Rauw Alejandro, Bizarrap             2           2023
# 25                         Fuerza Regida             1           2023
# 60              dennis, MC Kevin o Chris             2           2023
# 624                              Nirvana             1           1991
# 888                                Ghost             1           2019
# 630                          The Killers             1           2003
# 174                              YOASOBI             1           2023
# 849                         Paloma Faith             1           2014
# 879                            LF System             1           2022
# 871                        Guns N' Roses             1           1987
# 305                                   NF             1           2023
# 604                  Sean Paul, Dua Lipa             2           2016
# 264                                  IVE             1           2023
# 267                            SEVENTEEN             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 653               1             1                 31762                  0
# 51                4             6                  4277                 66
# 42                8            26                 12482                 80
# 121               3            10                  5120                 48
# 152               1             1                 17138                 37
# 102               4            14                  2528                 39
# 382               1            27                  2098                 16
# 132               1             1                  9389                 46
# 144               7            13                   437                 31
# 31                6            28                   266                 34
# 70                6            23                  1004                 35
# 25                6            22                   250                 26
# 60                5             4                   731                 15
# 624               9            10                 49991                  9
# 888               9            13                  2668                  2
# 630               9            23                 51979                 15
# 174               4            12                   356                 16
# 849               1             1                  5148                  0
# 879               5             2                  5898                  5
# 871               1             1                 41231                  1
# 305               3            25                   660                  0
# 604              11            18                  7370                  0
# 264               4            10                   366                 15
# 267               4            24                   271                 12
#
#           streams  in_apple_playlists  ...   mode  danceability_%  valence_%  \
# 653  8.433090e+08                 142  ...  Minor              92         31
# 51   1.777407e+08                 145  ...  Major              60         23
# 42   1.109433e+09                 291  ...  Minor              56         38
# 121  2.110508e+08                 161  ...  Major              64         31
# 152  1.279435e+09                 119  ...  Major              47         86
# 102  1.728259e+08                  56  ...  Major              50         37
# 382  1.342558e+08                  88  ...  Major              64         25
# 132  2.848199e+08                  24  ...  Major              42         20
# 144  1.159939e+07                  17  ...  Major              79         92
# 31   5.229427e+07                  20  ...  Major              56         63
# 70   5.426610e+07                  42  ...  Minor              77         84
# 25   7.830065e+07                  16  ...  Minor              79         96
# 60   1.119477e+08                  27  ...  Major              86         59
# 624  1.690193e+09                 265  ...  Major              52         73
# 888  3.870802e+08                  38  ...  Major              47         56
# 630  1.806618e+09                 306  ...  Major              35         24
# 174  1.435738e+08                  35  ...  Major              57         84
# 849  5.889553e+08                  90  ...  Major              57         30
# 879  2.447900e+08                 129  ...  Major              58         68
# 871  1.553498e+09                 228  ...  Major              45         67
# 305  5.272300e+07                  22  ...  Major              73         22
# 604  9.568653e+08                  92  ...  Major              74         45
# 264  1.231328e+08                  16  ...  Minor              68         38
# 267  9.122162e+07                  16  ...  Major              77         35
#
#      energy_%  acousticness_% instrumentalness_% liveness_%  speechiness_%  \
# 653        89               3                  0          8             25
# 51         91               0                  0         12              3
# 42         97               4                  0         35              4
# 121        87               4                  4          8              4
# 152        92               8                  0          5             24
# 102        90               0                  0         12              5
# 382        89               0                  0         15              9
# 132        86              21                  0          9              9
# 144        89               5                  0          6              5
# 31         87              39                  0         11              5
# 70         89              17                  0         43              5
# 25         86               9                  0          9              9
# 60         96              50                  1          9              5
# 624        91               0                  0         11              7
# 888        90               0                  0         10              4
# 630        93               0                  0         10              8
# 174        94              11                  0         37              9
# 849        89              10                  0         33              8
# 879        91               2                  0         27             11
# 871        90               9                 11         10              5
# 305        86              31                  0         12              4
# 604        89               5                  0         26             13
# 264        88               1                  0          8              5
# 267        88              16                  0         17              9
#
#      sum_playlist  energy_to_acoustic
# 653           NaN           29.666667
# 51         4635.0                 inf
# 42        13310.0           24.250000
# 121        5527.0           21.750000
# 152       18231.0           11.500000
# 102        2643.0                 inf
# 382        2287.0                 inf
# 132        9695.0            4.095238
# 144         480.0           17.800000
# 31          299.0            2.230769
# 70         1104.0            5.235294
# 25          276.0            9.555556
# 60          831.0            1.920000
# 624           NaN                 inf
# 888        2784.0                 inf
# 630           NaN                 inf
# 174         399.0            8.545455
# 849        5603.0            8.900000
# 879        6155.0           45.500000
# 871           NaN           10.000000
# 305         693.0            2.774194
# 604           NaN           17.800000
# 264         389.0           88.000000
# 267         296.0            5.500000
#
# [24 rows x 26 columns]

# %% [markdown]
# ## Zadanie 12.
#
# **Policz łączną liczbę playlist (Spotify + Apple + Deezer), w których występują wszystkie utwory razem.**
#
# **Rozwiązanie:**

# %%
df['in_spotify_playlists'].sum() + df['in_apple_playlists'].sum() + df['in_deezer_playlists'].sum()
# Out:
# np.float64(5116257.0)

# %% [markdown]
# ## Zadanie 13.
#
# **Czy utwory z wyższym `speechiness_%` mają niższą `valence_%` (czyli są bardziej „poważne”)?** Sprawdź korelację.
#
# **Rozwiązanie:**

# %%
df['speechiness_%'].corr(df['valence_%'])
#Nie
# Out:
# np.float64(0.04108109284898649)

# %% [markdown]
# ## Zadanie 14.
#
# **Który utwór ma największą wartość `streams` w stosunku do liczby playlist (`streams / playlist_sum`)?**
#
# **Rozwiązanie:**

# %%
df['proportion'] = df['streams'] / df['sum_playlist']
df.sort_values('proportion', ascending=False).head()
# Out:
#                                            track_name  \
# 425                                          Dream On
# 327        Peaches (from The Super Mario Bros. Movie)
# 619  Enemy - from the series Arcane League of Legends
# 344                     Apna Bana Le (From "Bhediya")
# 342                                              Sial
#
#                                  artist(s)_name  artist_count  released_year  \
# 425                                   Aerosmith             1           1973
# 327                                  Jack Black             1           2023
# 619  Imagine Dragons, League of Legends, Arcane             3           2021
# 344                  Arijit Singh, Sachin-Jigar             2           2022
# 342                                    Mahalini             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 425               1             5                   168                  0
# 327               4             7                    34                  0
# 619              10            27                   824                  0
# 344              11             5                    86                  0
# 342               1            23                   134                  4
#
#           streams  in_apple_playlists  ...  danceability_%  valence_%  \
# 425  8.385868e+08                   0  ...              39         24
# 327  6.821699e+07                   0  ...              71         41
# 619  1.223481e+09                   8  ...              73         54
# 344  1.398361e+08                  11  ...              59         44
# 342  1.665701e+08                   4  ...              56         20
#
#      energy_%  acousticness_%  instrumentalness_% liveness_% speechiness_%  \
# 425        43              39                   0         23             3
# 327        31              79                   0         10             5
# 619        74              23                   0         41            23
# 344        56              80                   0          6             3
# 342        43              89                   0         12             4
#
#      sum_playlist  energy_to_acoustic    proportion
# 425         173.0            1.102564  4.847322e+06
# 327          34.0            0.392405  2.006382e+06
# 619         840.0            3.217391  1.456525e+06
# 344          97.0            0.700000  1.441609e+06
# 342         138.0            0.483146  1.207029e+06
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Zadanie 15.
#
# **Znajdź wszystkie utwory wydane w lipcu (`released_month == 7`), które mają BPM powyżej średniego tempa w całej bazie.**
#
# **Rozwiązanie:**

# %%
mean_tempo = df['bpm'].mean()
df[(df['released_month'] == 7) & (df['bpm'] > mean_tempo)]
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 11                                           Super Shy
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# 30                                                Rush
# 58                                                 S91
# 59                                            cardigan
# 68                                           Overdrive
# 74               Quevedo: Bzrp Music Sessions, Vol. 52
# 76                                        Here With Me
# 83                 Back To December (Taylor's Version)
# 84                           STAY (with Justin Bieber)
# 104                                          New Jeans
# 122                                           Nonsense
# 139                                  Romantic Homicide
# 193             Better Than Revenge (Taylor's Version)
# 227                                             Normal
# 278                                          DESPECHï¿
# 360                                          Lovezinho
# 399                                                 TV
# 410                  INDUSTRY BABY (feat. Jack Harlow)
# 418                                               Doja
# 570                                    Volando - Remix
# 594                                             Sobrio
# 637                                Permission to Dance
# 875                     Hot Shit (feat. Ye & Lil Durk)
# 891              Come Back Home - From "Purple Hearts"
# 894  Stay With Me (with Justin Timberlake, Halsey, ...
# 924                            2 Be Loved (Am I Ready)
# 930                                Casei Com a Putaria
#
#                                         artist(s)_name  artist_count  \
# 0                                     Latto, Jung Kook             2
# 11                                            NewJeans             1
# 21                                        Taylor Swift             1
# 30                                         Troye Sivan             1
# 58                                             Karol G             1
# 59                                        Taylor Swift             1
# 68                                         Post Malone             1
# 74                                   Bizarrap, Quevedo             2
# 76                                                d4vd             1
# 83                                        Taylor Swift             1
# 84                        Justin Bieber, The Kid Laroi             2
# 104                                           NewJeans             1
# 122                                  Sabrina Carpenter             1
# 139                                               d4vd             1
# 193                                       Taylor Swift             1
# 227                                               Feid             1
# 278                                           ROSALï¿½             1
# 360                                             Treyce             1
# 399                                      Billie Eilish             1
# 410                             Jack Harlow, Lil Nas X             2
# 418                                        Central Cee             1
# 570                              Sech, Bad Bunny, Mora             3
# 594                                             Maluma             1
# 637                                                BTS             1
# 875                      Kanye West, Lil Durk, Cardi B             3
# 891                                       Sofia Carson             1
# 894  Calvin Harris, Halsey, Pharrell Williams, Just...             4
# 924                                              Lizzo             1
# 930                 MC Ryan SP, Love Funk, Mc Paiva ZS             3
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 11            2023               7             7                   422
# 21            2023               7             7                   516
# 30            2023               7            13                   864
# 58            2023               7            14                   525
# 59            2020               7            24                  7923
# 68            2023               7            14                   410
# 74            2022               7             6                  8506
# 76            2022               7            17                  3246
# 83            2023               7             7                   139
# 84            2021               7             9                 17050
# 104           2023               7             7                    77
# 122           2022               7            15                  2346
# 139           2022               7            20                  2335
# 193           2023               7             7                    86
# 227           2022               7             8                  2461
# 278           2022               7            28                  7613
# 360           2022               7            28                   242
# 399           2022               7            21                  3009
# 410           2021               7            23                 13315
# 418           2022               7            20                  4169
# 570           2021               7             8                  3272
# 594           2021               7             8                  3506
# 637           2021               7             9                  1801
# 875           2022               7             1                  1601
# 891           2022               7            12                   367
# 894           2022               7            15                  3113
# 924           2022               7            14                  3682
# 930           2022               7             1                   648
#
#      in_spotify_charts       streams  in_apple_playlists  ...  danceability_%  \
# 0                  147  1.413817e+08                  43  ...              80
# 11                  55  5.825515e+07                  37  ...              78
# 21                  38  5.213525e+07                  73  ...              69
# 30                  78  2.258116e+07                  71  ...              74
# 58                  41  1.601133e+07                  34  ...              86
# 59                  29  8.120196e+08                 106  ...              61
# 68                  36  1.478042e+07                  36  ...              56
# 74                  45  1.356565e+09                  94  ...              62
# 76                  23  6.354120e+08                  94  ...              58
# 83                  17  3.922893e+07                  16  ...              50
# 84                  36  2.665344e+09                 492  ...              59
# 104                 35  2.956222e+07                   8  ...              81
# 122                 27  3.428979e+08                  69  ...              74
# 139                 23  6.815831e+08                  82  ...              56
# 193                 11  3.034321e+07                   3  ...              50
# 227                 36  4.592764e+08                  47  ...              71
# 278                 33  7.823694e+08                 180  ...              92
# 360                  0  7.006974e+07                  12  ...              82
# 399                  2  3.385650e+08                  68  ...              41
# 410                  0  1.814350e+09                 300  ...              74
# 418                 44  4.822575e+08                  57  ...              91
# 570                 19  6.100456e+08                 101  ...              66
# 594                 10  5.136439e+08                 103  ...              76
# 637                  2  6.083340e+08                  77  ...              70
# 875                  0  8.592499e+07                  11  ...              88
# 891                  0  9.761045e+07                  28  ...              56
# 894                  0  1.234731e+08                  54  ...              81
# 924                  6  2.476891e+08                  41  ...              72
# 930                  4  1.877016e+08                   0  ...              59
#
#      valence_%  energy_%  acousticness_%  instrumentalness_% liveness_%  \
# 0           89        83              31                   0          8
# 11          52        82              18                   0         15
# 21          82        76               6                   0          6
# 30          35        84               0                   0         11
# 58          42        72              59                   0          9
# 59          53        58              55                   0         27
# 68          48        73               0                   0         35
# 74          55        78               1                   3         23
# 76          27        48              50                   0         12
# 83          20        64               1                   0         12
# 84          48        76               4                   0         10
# 104         53        72              51                   0         12
# 122         68        68               3                   0         26
# 139         20        55              45                   1         32
# 193         67        89               0                   0         19
# 227         59        56               4                   0         27
# 278         78        62              18                   0          6
# 360         61        59              30                   0         12
# 399          9        25              84                   1         14
# 410         89        70               2                   0          5
# 418         97        57              38                   0         40
# 570         63        69              21                   0         11
# 594         63        77              14                   0         15
# 637         65        74               1                   0         34
# 875         52        69               0                   0          8
# 891         43        53              24                   0         12
# 894         90        73              28                   0         29
# 924         92        77               9                   0          8
# 930         62        60              12                   0          5
#
#     speechiness_%  sum_playlist  energy_to_acoustic     proportion
# 0               4         641.0            2.677419  220564.279251
# 11              7         480.0            4.555556  121364.895833
# 21              3         631.0           12.666667   82623.213946
# 30              6         985.0                 inf   22925.036548
# 58             19         598.0            1.220339   26774.792642
# 59              4        8171.0            1.054545   99378.234855
# 68              4         477.0                 inf   30986.215933
# 74              4        8764.0           78.000000  154788.349270
# 76              3        3408.0            0.960000  186447.196303
# 83              3         160.0           64.000000  245180.806250
# 84              5       18340.0           19.000000  145329.548637
# 104             5          89.0            1.411765  332159.775281
# 122             4        2453.0           22.666667  139787.174073
# 139             3        2467.0            1.222222  276280.148358
# 193             8          92.0                 inf  329817.456522
# 227            12        2553.0           14.000000  179896.762632
# 278            10        8215.0            3.444444   95236.686914
# 360             4         267.0            1.966667  262433.501873
# 399             4        3142.0            0.297619  107754.608848
# 410             6       14305.0           35.000000  126833.258511
# 418            29        4409.0            1.500000  109380.234974
# 570             7        3443.0            3.285714  177184.322103
# 594            22        3709.0            5.500000  138485.824751
# 637             4        1952.0           74.000000  311646.540984
# 875            23        1614.0                 inf   53237.293680
# 891             4         590.0            2.208333  165441.433898
# 894             4        3291.0            2.607143   37518.419933
# 924            11        3881.0            8.555556   63820.954136
# 930            44         678.0            5.000000  276846.000000
#
# [29 rows x 27 columns]

# %% [markdown]
# ## Zadanie 16.
#
# **Sprawdź, czy bardziej energetyczne utwory mają też większy `liveness_%`.** (Porównaj średnie wartości.)
#
# **Rozwiązanie:**

# %%
df['energy_%'].corr(df['liveness_%'])
# Out:
# np.float64(0.11730178031427665)

# %% [markdown]
# ## Zadanie 17.
#
# **Znajdź wszystkie utwory, które mają `streams` powyżej średniej, ale są w mniej niż 100 playlistach Spotify.**
#
# **Rozwiązanie:**

# %%
streams_mean = df['streams'].mean()
df[(df['streams'] > streams_mean) & (df['in_spotify_playlists'] < 100)]
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%, sum_playlist, energy_to_acoustic, proportion]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ## Zadanie 18.
#
# **Które utwory są najbardziej „zbalansowane”? Tzn. mają `danceability_%`, `energy_%` i `valence_%` zbliżone do średnich (różnice < 10).** Porównaj do średnich za pomocą `abs()`.
#
# **Rozwiązanie:**

# %%
mean_danceability = df['danceability_%'].mean()
mean_energy = df['energy_%'].mean()
mean_valence = df['valence_%'].mean()
df[(abs(df['danceability_%'] - mean_danceability) < 10) & (abs(df['energy_%'] - mean_energy) < 10) & (abs(df['valence_%'] - mean_valence) < 10)]
# Out:
#                                 track_name  \
# 1                                     LALA
# 10                               un x100to
# 15                               Kill Bill
# 33                               Anti-Hero
# 34                                     TQG
# ..                                     ...
# 855                 Crazy What Love Can Do
# 885           Si Te La Encuentras Por Ahï¿
# 906                             Ferxxo 100
# 932  Pussy & Millions (feat. Travis Scott)
# 947                          The Great War
#
#                                artist(s)_name  artist_count  released_year  \
# 1                                 Myke Towers             1           2023
# 10                  Bad Bunny, Grupo Frontera             2           2023
# 15                                        SZA             1           2022
# 33                               Taylor Swift             1           2022
# 34                           Karol G, Shakira             2           2023
# ..                                        ...           ...            ...
# 855  David Guetta, Ella Henderson, Becky Hill             3           2022
# 885                                      Feid             1           2022
# 906                                      Feid             1           2022
# 932            Drake, Travis Scott, 21 Savage             3           2022
# 947                              Taylor Swift             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 1                 3            23                  1474                 48
# 10                4            17                  2876                 40
# 15               12             8                  8109                 77
# 33               10            21                  9082                 56
# 34                2            23                  4284                 49
# ..              ...           ...                   ...                ...
# 855               3            18                  5290                  0
# 885               8             5                  1379                  4
# 906               6             3                  1647                 30
# 932              11             4                  1930                  0
# 947              10            21                  1274                  0
#
#           streams  in_apple_playlists  ...  danceability_%  valence_%  \
# 1    1.337163e+08                  48  ...              71         61
# 10   5.056714e+08                  41  ...              57         56
# 15   1.163094e+09                 183  ...              64         43
# 33   9.997483e+08                 242  ...              64         51
# 34   6.189904e+08                 115  ...              72         61
# ..            ...                 ...  ...             ...        ...
# 855  2.867395e+08                 139  ...              60         46
# 885  1.790614e+08                  23  ...              74         46
# 906  2.789200e+08                  20  ...              70         58
# 932  1.913337e+08                  24  ...              75         45
# 947  1.813826e+08                   1  ...              57         55
#
#      energy_%  acousticness_%  instrumentalness_% liveness_% speechiness_%  \
# 1          74               7                   0         10             4
# 10         72              23                   0         27             5
# 15         73               5                  17         16             4
# 33         63              12                   0         19             5
# 34         63              67                   0          9            28
# ..        ...             ...                 ...        ...           ...
# 855        71               3                   0         16             4
# 885        58              15                   0         13             8
# 906        57              25                   0         15             7
# 932        63               6                   0         35            12
# 947        74              22                   0          8             4
#
#      sum_playlist  energy_to_acoustic     proportion
# 1          1580.0           10.571429   84630.560759
# 10         2971.0            3.130435  170202.436217
# 15         8453.0           14.600000  137595.368981
# 33         9489.0            5.250000  105358.654969
# 34         4583.0            0.940299  135062.272093
# ..            ...                 ...            ...
# 855        5571.0           23.666667   51470.019027
# 885        1420.0            3.866667  126099.605634
# 906        1690.0            2.280000  165041.424260
# 932        1971.0           10.500000   97074.406900
# 947        1286.0            3.363636  141044.004666
#
# [65 rows x 27 columns]

# %% [markdown]
# ## Zadanie 19.
#
# **Oblicz całkowitą liczbę artystów w bazie (`artist_count`).**
#
# **Rozwiązanie:**

# %%
df['artist(s)_name'].unique().shape
# Out:
# (645,)

# %% [markdown]
# ## Zadanie 20.
#
# **Zbadaj zależność między tanecznością a mówionością (`speechiness_%`) — czy bardziej taneczne utwory są mniej „gadane”?**
#
# **Rozwiązanie:**

# %%
df['danceability_%'].corr(df['speechiness_%'])
# raczej nie
# Out:
# np.float64(0.18497711241491455)

# %% [markdown]
# ## Zadanie 21
#
# Srednie procenty piosenek Ye

# %%
df[df['artist(s)_name'] == 'Kanye West'][[x for x in df.columns if '%' in x]].mean()
#Ma tylko 3 piosenki
# Out:
# danceability_%        65.333333
# valence_%             38.333333
# energy_%              62.000000
# acousticness_%         6.666667
# instrumentalness_%     0.000000
# liveness_%            20.000000
# speechiness_%         12.000000
# dtype: float64

# %%
df[df['artist(s)_name'] == 'Kanye West']
# Out:
#      track_name artist(s)_name  artist_count  released_year  released_month  \
# 589  Praise God     Kanye West             1           2021               8
# 893   Heartless     Kanye West             1           2008               1
# 902     Bound 2     Kanye West             1           2013               1
#
#      released_day  in_spotify_playlists  in_spotify_charts      streams  \
# 589            29                  4651                  0  376333030.0
# 893             1                 17504                 34  887906111.0
# 902             1                 19806                  7  703301727.0
#
#      in_apple_playlists  ...  key   mode  danceability_%  valence_%  energy_%  \
# 589                  24  ...   C#  Major              80         21        55
# 893                  63  ...   A#  Minor              79         66        65
# 902                  33  ...   C#  Major              37         28        66
#
#     acousticness_% instrumentalness_%  liveness_%  speechiness_%  sum_playlist
# 589              1                  0          26             17        4780.0
# 893              5                  0          25             14           NaN
# 902             14                  0           9              5       20113.0
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Zadanie 22
#
# Kto ma najwiecej piosenek w tym zbiorze danych

# %%
df.groupby('artist(s)_name').agg({'track_name' : 'count'}).sort_values('track_name', ascending=False).head(10)
# Out:
#                   track_name
# artist(s)_name
# Taylor Swift              34
# The Weeknd                22
# SZA                       19
# Bad Bunny                 19
# Harry Styles              17
# Kendrick Lamar            12
# Morgan Wallen             11
# Ed Sheeran                 9
# Drake, 21 Savage           8
# BTS                        8
